# %% [markdown]
# # Load Dataset

# %%
import pandas as pd
from io import StringIO
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer
from datasets import Dataset

# %%
# Load the JSON Lines file into a DataFrame
data_path = "../data/jutsus.jsonl"
df = pd.read_json(data_path, lines=True)

# Display the first few rows
df.head()


# import pandas as pd
# import json

# # Manually read the file and parse each line into a list of dictionaries
# data_path = "../data/jutsus.jsonl"
# with open(data_path, 'r') as file:
#     data = [json.loads(line) for line in file if line.strip()]  # Skip empty lines

# # Convert the list of dictionaries into a DataFrame
# df = pd.DataFrame(data)

# # Display the first few rows
# df.head()
# Out:
#                   jutsu_name                        jutsu_type  \
# 0               Azure Stream         Hiden, Ninjutsu, Kenjutsu
# 1               Asura Attack  Kekkei Genkai, Ninjutsu, Dōjutsu
# 2          100% Single Punch                          Taijutsu
# 3               10 Hit Combo                          Taijutsu
# 4  Attack of the Twin Demons           Kekkei Genkai, Ninjutsu
#
#                                    jutsu_description
# 0  Suigetsu creates a moving body of water beneat...
# 1  With the body modifications of the Asura Path,...
# 2  Tsunade gathers large amounts of chakra in her...
# 3  Lars punches the opponent before striking them...
# 4  This technique allows Ukon to inhabit his brot...

# %%
# data_path = "../data/jutsus.jsonl"

# with open(data_path, 'r') as file:
#     lines = file.readlines()
#     for line in lines[:5]:  # Print the first 5 lines to inspect
#      print(line)

# %%
def simplify_justsu(jutsu):
    if "Genjutsu" in jutsu:
        return "Genjutsu"
    
    if "Ninjutsu" in jutsu:
        return "Ninjutsu"
    
    if "Taijutsu" in jutsu:
        return "Taijutsu"

# %%
df['jutsu_type_Simplified'] = df['jutsu_type'].apply(simplify_justsu)
df
# Out:
#                        jutsu_name                          jutsu_type  \
# 0                    Azure Stream           Hiden, Ninjutsu, Kenjutsu
# 1                    Asura Attack    Kekkei Genkai, Ninjutsu, Dōjutsu
# 2               100% Single Punch                            Taijutsu
# 3                    10 Hit Combo                            Taijutsu
# 4       Attack of the Twin Demons             Kekkei Genkai, Ninjutsu
# ...                           ...                                 ...
# 2920            Absorption Sphere                            Ninjutsu
# 2921  Absolute: Fang Passing Fang  Taijutsu, Collaboration Techniques
# 2922             1000 Metre Punch                            Taijutsu
# 2923                 16 Hit Combo                            Taijutsu
# 2924                      Acrobat                  Taijutsu, Kenjutsu
#
#                                       jutsu_description jutsu_type_Simplified
# 0     Suigetsu creates a moving body of water beneat...              Ninjutsu
# 1     With the body modifications of the Asura Path,...              Ninjutsu
# 2     Tsunade gathers large amounts of chakra in her...              Taijutsu
# 3     Lars punches the opponent before striking them...              Taijutsu
# 4     This technique allows Ukon to inhabit his brot...              Ninjutsu
# ...                                                 ...                   ...
# 2920  Using the Jutsu Absorption Arm, the user creat...              Ninjutsu
# 2921  Kiba and Akamaru perform the Fang Passing Fang...              Taijutsu
# 2922  The user focuses a large amount of chakra into...              Taijutsu
# 2923  A very effective move, Ino uses this as a quic...              Taijutsu
# 2924  The Acrobat (荒繰鷺伐刀, Akurobatto) is a kenjutsu ...              Taijutsu
#
# [2925 rows x 4 columns]

# %%
df['jutsu_type_Simplified'].value_counts()

#skewed dataset
# Out:
# jutsu_type_Simplified
# Ninjutsu    2258
# Taijutsu     398
# Genjutsu     101
# Name: count, dtype: int64

# %%
df['text'] = df['jutsu_name'] + ". " + df['jutsu_description']
df['jutsu'] = df['jutsu_type_Simplified']
df = df[['text', 'jutsu']]
df = df.dropna()

# %%
df.head()
# Out:
#                                                 text     jutsu
# 0  Azure Stream. Suigetsu creates a moving body o...  Ninjutsu
# 1  Asura Attack. With the body modifications of t...  Ninjutsu
# 2  100% Single Punch. Tsunade gathers large amoun...  Taijutsu
# 3  10 Hit Combo. Lars punches the opponent before...  Taijutsu
# 4  Attack of the Twin Demons. This technique allo...  Ninjutsu

# %%
#cleaning purpose

from bs4 import BeautifulSoup
class Cleaner():
    def __init__(self):
        pass 
    
    def put_line_breaks(self, text):
        return text.replace("<\p>", "<\p>\n")
    
    def remove_html_tags(self, text):
        clean_text = BeautifulSoup(text, "lxml").text
        return clean_text

    def clean(self, text):
        text = self.put_line_breaks(text)
        text = self.remove_html_tags(text)
        text = text.strip()
        return text

# %%
text_column_name = 'text'
label_column_name = 'jutsu'

# %%
df.head(3)
# Out:
#                                                 text     jutsu
# 0  Azure Stream. Suigetsu creates a moving body o...  Ninjutsu
# 1  Asura Attack. With the body modifications of t...  Ninjutsu
# 2  100% Single Punch. Tsunade gathers large amoun...  Taijutsu

# %%
# Clean Text
cleaner = Cleaner()
df['text_cleaned'] = df[text_column_name].apply(cleaner.clean)
# Out:
# C:\Users\nitis\AppData\Local\Temp\ipykernel_9616\2483218578.py:12: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text, "lxml").text

# %%
df.head(3)
# Out:
#                                                 text     jutsu  \
# 0  Azure Stream. Suigetsu creates a moving body o...  Ninjutsu
# 1  Asura Attack. With the body modifications of t...  Ninjutsu
# 2  100% Single Punch. Tsunade gathers large amoun...  Taijutsu
#
#                                         text_cleaned
# 0  Azure Stream. Suigetsu creates a moving body o...
# 1  Asura Attack. With the body modifications of t...
# 2  100% Single Punch. Tsunade gathers large amoun...

# %%
# Encode Labels 
le = preprocessing.LabelEncoder()
le.fit(df[label_column_name].tolist())
# Out:
# LabelEncoder()

# %%
label_dict = {index:label_name for index, label_name in enumerate(le.__dict__['classes_'].tolist())}
label_dict
# Out:
# {0: 'Genjutsu', 1: 'Ninjutsu', 2: 'Taijutsu'}

# %%
df['label'] = le.transform(df[label_column_name].tolist())

# %%
df.sample(4)
# Out:
#                                                    text     jutsu  \
# 2229  Fire Release: Big Flame Bullet. This technique...  Ninjutsu
# 16    Cat Genjutsu. The user uses a genjutsu where t...  Genjutsu
# 1799  Lava Release: Scorching Flow Peak Rock. Rōshi ...  Ninjutsu
# 835   Truth-Seeking: Pure Shadow. Obito encases hims...  Ninjutsu
#
#                                            text_cleaned  label
# 2229  Fire Release: Big Flame Bullet. This technique...      1
# 16    Cat Genjutsu. The user uses a genjutsu where t...      0
# 1799  Lava Release: Scorching Flow Peak Rock. Rōshi ...      1
# 835   Truth-Seeking: Pure Shadow. Obito encases hims...      1

# %%
# training and testing

test_size = 0.2
df_train, df_test = train_test_split(df,
                                     test_size = test_size,
                                     stratify=df['label'])

# %%
df_train['jutsu'].value_counts()
# Out:
# jutsu
# Ninjutsu    1806
# Taijutsu     318
# Genjutsu      81
# Name: count, dtype: int64

# %%
model_name = "distilbert/distilbert-base-uncased"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# d:\projects\analyse_naruto_series2\naruto_envr\Lib\site-packages\huggingface_hub\file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# d:\projects\analyse_naruto_series2\naruto_envr\Lib\site-packages\huggingface_hub\file_download.py:159: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\nitis\.cache\huggingface\hub\models--distilbert--distilbert-base-uncased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
def preprocess_function(tokenizer,examples):
    return tokenizer(examples['text_cleaned'],truncation=True)

# %%
# Conver Pandas to a hugging face dataset
train_dataset = Dataset.from_pandas(df_train)
test_dataset = Dataset.from_pandas(df_test)

# tokenize the dataset
tokenized_train = train_dataset.map(lambda examples: preprocess_function(tokenizer, examples),
                                    batched=True)
tokenized_test = test_dataset.map(lambda examples: preprocess_function(tokenizer, examples),
                                    batched=True)
# Out:
# Map: 100%|██████████| 2205/2205 [00:00<00:00, 10744.92 examples/s]
# Map: 100%|██████████| 552/552 [00:00<00:00, 10776.20 examples/s]
